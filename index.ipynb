# %% [markdown]
# # Accessing Data within Pandas - Lab

# %% [markdown]
# ## Introduction
#
# In this lab, we'll look at a data set which contains information World cup matches. Let's use the pandas commands learned in the previous lecture to learn more about our data!

# %% [markdown]
# ## Objectives
# You will be able to:
# * Understand and explain some key Pandas methods
# * Access DataFrame data by using the label
# * Perform boolean indexing on both Series and DataFrames
# * Use simple selectors for series
# * Set new Series and DataFrame inputs

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load the file `WorldCupMatches.csv` as a dataframe in Pandas

# %%
import pandas as pd
df = pd.read_csv('WorldCupMatches.csv')
df.head()
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                     3                     0
# 1                    18346.0                     2                     0
# 2                    24059.0                     2                     0
# 3                     2549.0                     1                     0
# 4                    23409.0                     0                     0
#
#                   Referee               Assistant 1  \
# 0  LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1       MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2     TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3   WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4     REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
#
#                   Assistant 2  RoundID  MatchID Home Team Initials  \
# 0         REGO Gilberto (BRA)      201     1096                FRA
# 1       WARNKEN Alberto (CHI)      201     1090                USA
# 2         BALWAY Thomas (FRA)      201     1093                YUG
# 3    MATEUCCI Francisco (URU)      201     1098                ROU
# 4  RADULESCU Constantin (ROU)      201     1085                ARG
#
#   Away Team Initials
# 0                MEX
# 1                BEL
# 2                BRA
# 3                PER
# 4                FRA

# %% [markdown]
# ## Common methods and attributes

# %% [markdown]
# Use the correct method to look at the first 7 rows of the data set.

# %%
df.head(7)
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# 5  1930  16 Jul 1930 - 14:45   Group 1  Parque Central  Montevideo
# 6  1930  17 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
# 5          Chile                3                0         Mexico
# 6     Yugoslavia                4                0        Bolivia
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                     3                     0
# 1                    18346.0                     2                     0
# 2                    24059.0                     2                     0
# 3                     2549.0                     1                     0
# 4                    23409.0                     0                     0
# 5                     9249.0                     1                     0
# 6                    18306.0                     0                     0
#
#                     Referee               Assistant 1  \
# 0    LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1         MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2       TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3     WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4       REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
# 5     CRISTOPHE Henry (BEL)   APHESTEGUY Martin (URU)
# 6  MATEUCCI Francisco (URU)    LOMBARDI Domingo (URU)
#
#                   Assistant 2  RoundID  MatchID Home Team Initials  \
# 0         REGO Gilberto (BRA)      201     1096                FRA
# 1       WARNKEN Alberto (CHI)      201     1090                USA
# 2         BALWAY Thomas (FRA)      201     1093                YUG
# 3    MATEUCCI Francisco (URU)      201     1098                ROU
# 4  RADULESCU Constantin (ROU)      201     1085                ARG
# 5         LANGENUS Jean (BEL)      201     1095                CHI
# 6       WARNKEN Alberto (CHI)      201     1092                YUG
#
#   Away Team Initials
# 0                MEX
# 1                BEL
# 2                BRA
# 3                PER
# 4                FRA
# 5                MEX
# 6                BOL

# %% [markdown]
# Look at the last 3 rows of the data set.

# %%
df.tail(7)
# Out:
#      Year              Datetime                     Stage  \
# 845  2014  04 Jul 2014 - 17:00             Quarter-finals
# 846  2014  05 Jul 2014 - 13:00             Quarter-finals
# 847  2014  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014  08 Jul 2014 - 17:00                Semi-finals
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 845     Estadio Castelao       Fortaleza          Brazil                2
# 846     Estadio Nacional        Brasilia       Argentina                1
# 847     Arena Fonte Nova        Salvador     Netherlands                0
# 848     Estadio Mineirao  Belo Horizonte          Brazil                1
# 849   Arena de Sao Paulo       Sao Paulo     Netherlands                0
# 850     Estadio Nacional        Brasilia          Brazil                0
# 851  Estadio do Maracana  Rio De Janeiro         Germany                1
#
#      Away Team Goals Away Team Name                         Win conditions  \
# 845                1       Colombia
# 846                0        Belgium
# 847                0     Costa Rica  Netherlands win on penalties (4 - 3)
# 848                7        Germany
# 849                0      Argentina    Argentina win on penalties (2 - 4)
# 850                3    Netherlands
# 851                0      Argentina          Germany win after extra time
#
#      Attendance  Half-time Home Goals  Half-time Away Goals  \
# 845     60342.0                     1                     0
# 846     68551.0                     1                     0
# 847     51179.0                     0                     0
# 848     58141.0                     0                     5
# 849     63267.0                     0                     0
# 850     68034.0                     0                     2
# 851     74738.0                     0                     0
#
#                            Referee                     Assistant 1  \
# 845  Carlos VELASCO CARBALLO (ESP)  ALONSO FERNANDEZ Roberto (ESP)
# 846           Nicola RIZZOLI (ITA)           Renato FAVERANI (ITA)
# 847          Ravshan IRMATOV (UZB)     RASULOV Abduxamidullo (UZB)
# 848          RODRIGUEZ Marco (MEX)         TORRENTERA Marvin (MEX)
# 849             C�neyt �AKIR (TUR)            DURAN Bahattin (TUR)
# 850          HAIMOUDI Djamel (ALG)            ACHIK Redouane (MAR)
# 851           Nicola RIZZOLI (ITA)           Renato FAVERANI (ITA)
#
#                   Assistant 2  RoundID    MatchID Home Team Initials  \
# 845          YUSTE Juan (ESP)   255953  300186461                BRA
# 846      Andrea STEFANI (ITA)   255953  300186504                ARG
# 847  KOCHKAROV Bakhadyr (KGZ)   255953  300186488                NED
# 848     QUINTERO Marcos (MEX)   255955  300186474                BRA
# 849         ONGUN Tarik (TUR)   255955  300186490                NED
# 850   ETCHIALI Abdelhak (ALG)   255957  300186502                BRA
# 851      Andrea STEFANI (ITA)   255959  300186501                GER
#
#     Away Team Initials
# 845                COL
# 846                BEL
# 847                CRC
# 848                GER
# 849                ARG
# 850                NED
# 851                ARG

# %% [markdown]
# Get a concise summary of your data using `.info()`

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852 entries, 0 to 851
# Data columns (total 20 columns):
# Year                    852 non-null int64
# Datetime                852 non-null object
# Stage                   852 non-null object
# Stadium                 852 non-null object
# City                    852 non-null object
# Home Team Name          852 non-null object
# Home Team Goals         852 non-null int64
# Away Team Goals         852 non-null int64
# Away Team Name          852 non-null object
# Win conditions          852 non-null object
# Attendance              850 non-null float64
# Half-time Home Goals    852 non-null int64
# Half-time Away Goals    852 non-null int64
# Referee                 852 non-null object
# Assistant 1             852 non-null object
# Assistant 2             852 non-null object
# RoundID                 852 non-null int64
# MatchID                 852 non-null int64
# Home Team Initials      852 non-null object
# Away Team Initials      852 non-null object
# dtypes: float64(1), int64(7), object(12)
# memory usage: 133.2+ KB

# %% [markdown]
# Obtain a tuple representing the number of rows and number of columns

# %%
df.shape
# Out:
# (852, 20)

# %% [markdown]
# Use the appropriate attribute to get the column names

# %%
df.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %% [markdown]
# ## Selecting dataframe information

# %% [markdown]
# When looking at the dataframe's `.head()`, you might have noticed that the games are structured chronologically in the dataframe.
#
# Use the right selection method to print all the information from the 3rd to the 5th game.

# %%
df.loc[3:6]
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# 5  1930  16 Jul 1930 - 14:45   Group 1  Parque Central  Montevideo
# 6  1930  17 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
# 5          Chile                3                0         Mexico
# 6     Yugoslavia                4                0        Bolivia
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 3                     2549.0                     1                     0
# 4                    23409.0                     0                     0
# 5                     9249.0                     1                     0
# 6                    18306.0                     0                     0
#
#                     Referee              Assistant 1  \
# 3     WARNKEN Alberto (CHI)      LANGENUS Jean (BEL)
# 4       REGO Gilberto (BRA)     SAUCEDO Ulises (BOL)
# 5     CRISTOPHE Henry (BEL)  APHESTEGUY Martin (URU)
# 6  MATEUCCI Francisco (URU)   LOMBARDI Domingo (URU)
#
#                   Assistant 2  RoundID  MatchID Home Team Initials  \
# 3    MATEUCCI Francisco (URU)      201     1098                ROU
# 4  RADULESCU Constantin (ROU)      201     1085                ARG
# 5         LANGENUS Jean (BEL)      201     1095                CHI
# 6       WARNKEN Alberto (CHI)      201     1092                YUG
#
#   Away Team Initials
# 3                PER
# 4                FRA
# 5                MEX
# 6                BOL

# %% [markdown]
# Now, print all the info from game 5-9, but we're only interested to print out the "Home Team Name" and the "Away Team Name",

# %%
df.loc[5:9,["Home Team Name","Away Team Name"]]
# Out:
#   Home Team Name Away Team Name
# 5          Chile         Mexico
# 6     Yugoslavia        Bolivia
# 7            USA       Paraguay
# 8        Uruguay           Peru
# 9          Chile         France

# %% [markdown]
# Next, we'd like the information on all the games played in Group 3 for the 1950 World Cup.

# %%
##df.loc[df["Year"]==1950]
df.loc[(df["Stage"]=="Group 3") & (df["Year"]==1950)]
# Out:
#     Year              Datetime    Stage           Stadium        City  \
# 56  1950  25 Jun 1950 - 15:00   Group 3          Pacaembu  Sao Paulo
# 61  1950  29 Jun 1950 - 15:30   Group 3  Durival de Brito   Curitiba
# 65  1950  02 Jul 1950 - 15:00   Group 3          Pacaembu  Sao Paulo
#
#    Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 56         Sweden                3                2          Italy
# 61         Sweden                2                2       Paraguay
# 65          Italy                2                0       Paraguay
#
#    Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 56                    36502.0                     2                     1
# 61                     7903.0                     2                     1
# 65                    25811.0                     1                     0
#
#                   Referee             Assistant 1                Assistant 2  \
# 56        LUTZ Jean (SUI)     BERANEK Alois (AUT)        TEJADA Carlos (MEX)
# 61  MITCHELL Robert (SCO)       LEMESIC Leo (YUG)     GARCIA Prudencio (USA)
# 65     ELLIS Arthur (ENG)  GARCIA Prudencio (USA)  DE LA SALLE Charles (FRA)
#
#     RoundID  MatchID Home Team Initials Away Team Initials
# 56      208     1219                SWE                ITA
# 61      208     1228                SWE                PAR
# 65      208     1218                ITA                PAR

# %% [markdown]
# Let's repeat the command above, but now we only want to print out the attendance column for the Group 3 games

# %% [markdown]
# You can combine conditions like this:
#
# `df[(condition1) | (condition2)]`  -> Returns rows where either condition is true
#
# `df[(condition1) & (condition2)]`  -> Returns rows where both conditions are true

# %%
df.loc[(df["Stage"]=="Group 3") | (df["Year"]==1950)]
# Out:
#      Year              Datetime    Stage  \
# 3    1930  14 Jul 1930 - 14:50   Group 3
# 8    1930  18 Jul 1930 - 14:30   Group 3
# 13   1930  21 Jul 1930 - 14:50   Group 3
# 53   1950  24 Jun 1950 - 15:00   Group 1
# 54   1950  25 Jun 1950 - 15:00   Group 2
# 55   1950  25 Jun 1950 - 15:00   Group 2
# 56   1950  25 Jun 1950 - 15:00   Group 3
# 57   1950  25 Jun 1950 - 15:00   Group 1
# 58   1950  28 Jun 1950 - 15:00   Group 1
# 59   1950  28 Jun 1950 - 15:00   Group 1
# 60   1950  29 Jun 1950 - 15:00   Group 2
# 61   1950  29 Jun 1950 - 15:30   Group 3
# 62   1950  29 Jun 1950 - 15:00   Group 2
# 63   1950  01 Jul 1950 - 15:00   Group 1
# 64   1950  02 Jul 1950 - 15:00   Group 2
# 65   1950  02 Jul 1950 - 15:00   Group 3
# 66   1950  02 Jul 1950 - 15:00   Group 4
# 67   1950  02 Jul 1950 - 15:40   Group 1
# 68   1950  02 Jul 1950 - 15:00   Group 2
# 69   1950  09 Jul 1950 - 15:00   Group 6
# 70   1950  09 Jul 1950 - 15:00   Group 6
# 71   1950  13 Jul 1950 - 15:00   Group 6
# 72   1950  13 Jul 1950 - 15:00   Group 6
# 73   1950  16 Jul 1950 - 15:00   Group 6
# 74   1950  16 Jul 1950 - 15:00   Group 6
# 75   1954  16 Jun 1954 - 18:00   Group 3
# 76   1954  16 Jun 1954 - 18:00   Group 3
# 83   1954  19 Jun 1954 - 16:50   Group 3
# 84   1954  19 Jun 1954 - 17:00   Group 3
# 101  1958  08 Jun 1958 - 14:00   Group 3
# ..    ...                   ...      ...
# 180  1966  16 Jul 1966 - 15:00   Group 3
# 186  1966  19 Jul 1966 - 19:30   Group 3
# 189  1966  20 Jul 1966 - 19:30   Group 3
# 203  1970  02 Jun 1970 - 16:00   Group 3
# 206  1970  03 Jun 1970 - 16:00   Group 3
# 210  1970  06 Jun 1970 - 16:00   Group 3
# 214  1970  07 Jun 1970 - 12:00   Group 3
# 218  1970  10 Jun 1970 - 16:00   Group 3
# 222  1970  11 Jun 1970 - 16:00   Group 3
# 236  1974  15 Jun 1974 - 16:00   Group 3
# 237  1974  15 Jun 1974 - 16:00   Group 3
# 244  1974  19 Jun 1974 - 19:30   Group 3
# 245  1974  19 Jun 1974 - 19:30   Group 3
# 252  1974  23 Jun 1974 - 16:00   Group 3
# 254  1974  23 Jun 1974 - 16:00   Group 3
# 274  1978  03 Jun 1978 - 13:45   Group 3
# 275  1978  03 Jun 1978 - 13:45   Group 3
# 282  1978  07 Jun 1978 - 13:45   Group 3
# 283  1978  07 Jun 1978 - 13:45   Group 3
# 290  1978  11 Jun 1978 - 13:45   Group 3
# 291  1978  11 Jun 1978 - 13:45   Group 3
# 308  1982  13 Jun 1982 - 20:00   Group 3
# 312  1982  15 Jun 1982 - 21:00   Group 3
# 321  1982  18 Jun 1982 - 21:00   Group 3
# 324  1982  19 Jun 1982 - 21:00   Group 3
# 333  1982  22 Jun 1982 - 21:00   Group 3
# 336  1982  23 Jun 1982 - 21:00   Group 3
# 346  1982  29 Jun 1982 - 17:15   Group 3
# 350  1982  02 Jul 1982 - 17:15   Group 3
# 354  1982  05 Jul 1982 - 17:15   Group 3
#
#                                        Stadium             City  \
# 3                                      Pocitos      Montevideo
# 8                           Estadio Centenario      Montevideo
# 13                          Estadio Centenario      Montevideo
# 53   Maracan� - Est�dio Jornalista M�rio Filho  Rio De Janeiro
# 54   Maracan� - Est�dio Jornalista M�rio Filho  Rio De Janeiro
# 55                            Durival de Brito        Curitiba
# 56                                    Pacaembu       Sao Paulo
# 57                               Independencia  Belo Horizonte
# 58                                    Pacaembu       Sao Paulo
# 59                                  Eucaliptos    Porto Alegre
# 60   Maracan� - Est�dio Jornalista M�rio Filho  Rio De Janeiro
# 61                            Durival de Brito        Curitiba
# 62                               Independencia  Belo Horizonte
# 63   Maracan� - Est�dio Jornalista M�rio Filho  Rio De Janeiro
# 64   Maracan� - Est�dio Jornalista M�rio Filho  Rio De Janeiro
# 65                                    Pacaembu       Sao Paulo
# 66                               Independencia  Belo Horizonte
# 67                                  Eucaliptos    Porto Alegre
# 68                              Ilha do Retiro          Recife
# 69                                    Pacaembu       Sao Paulo
# 70   Maracan� - Est�dio Jornalista M�rio Filho  Rio De Janeiro
# 71   Maracan� - Est�dio Jornalista M�rio Filho  Rio De Janeiro
# 72                                    Pacaembu       Sao Paulo
# 73                                    Pacaembu       Sao Paulo
# 74   Maracan� - Est�dio Jornalista M�rio Filho  Rio De Janeiro
# 75                            Wankdorf Stadium           Berne
# 76                                    Hardturm          Zurich
# 83                                   St. Jakob           Basel
# 84                                    Hardturm          Zurich
# 101                            Rasunda Stadium           Solna
# ..                                         ...              ...
# 180                       Old Trafford Stadium      Manchester
# 186                              Goodison Park       Liverpool
# 189                       Old Trafford Stadium      Manchester
# 203                                    Jalisco     Guadalajara
# 206                                    Jalisco     Guadalajara
# 210                                    Jalisco     Guadalajara
# 214                                    Jalisco     Guadalajara
# 218                                    Jalisco     Guadalajara
# 222                                    Jalisco     Guadalajara
# 236                       Niedersachsenstadion         Hanover
# 237                               Rheinstadion      D�Sseldorf
# 244                           Westfalenstadion        Dortmund
# 245                       Niedersachsenstadion         Hanover
# 252                           Westfalenstadion        Dortmund
# 254                               Rheinstadion      D�Sseldorf
# 274                 Estadio Jos� Mar�a Minella   Mar Del Plata
# 275                            Jose Amalfitani    Buenos Aires
# 282                 Estadio Jos� Mar�a Minella   Mar Del Plata
# 283                            Jose Amalfitani    Buenos Aires
# 290                 Estadio Jos� Mar�a Minella   Mar Del Plata
# 291                            Jose Amalfitani    Buenos Aires
# 308                                   Camp Nou       Barcelona
# 312                              Nuevo Estadio           Elche
# 321                            Jose Rico Perez        Alicante
# 324                              Nuevo Estadio           Elche
# 333                              Nuevo Estadio           Elche
# 336                            Jose Rico Perez        Alicante
# 346                                     Sarria       Barcelona
# 350                                     Sarria       Barcelona
# 354                                     Sarria       Barcelona
#
#     Home Team Name  Home Team Goals  Away Team Goals  Away Team Name  \
# 3          Romania                3                1            Peru
# 8          Uruguay                1                0            Peru
# 13         Uruguay                4                0         Romania
# 53          Brazil                4                0          Mexico
# 54         England                2                0           Chile
# 55           Spain                3                1             USA
# 56          Sweden                3                2           Italy
# 57      Yugoslavia                3                0     Switzerland
# 58          Brazil                2                2     Switzerland
# 59      Yugoslavia                4                1          Mexico
# 60           Spain                2                0           Chile
# 61          Sweden                2                2        Paraguay
# 62             USA                1                0         England
# 63          Brazil                2                0      Yugoslavia
# 64           Spain                1                0         England
# 65           Italy                2                0        Paraguay
# 66         Uruguay                8                0         Bolivia
# 67     Switzerland                2                1          Mexico
# 68           Chile                5                2             USA
# 69         Uruguay                2                2           Spain
# 70          Brazil                7                1          Sweden
# 71          Brazil                6                1           Spain
# 72         Uruguay                3                2          Sweden
# 73          Sweden                3                1           Spain
# 74         Uruguay                2                1          Brazil
# 75         Uruguay                2                0  Czechoslovakia
# 76         Austria                1                0        Scotland
# 83         Uruguay                7                0        Scotland
# 84         Austria                5                0  Czechoslovakia
# 101         Sweden                3                0          Mexico
# ..             ...              ...              ...             ...
# 180       Portugal                3                0        Bulgaria
# 186       Portugal                3                1          Brazil
# 189        Hungary                3                1        Bulgaria
# 203        England                1                0         Romania
# 206         Brazil                4                1  Czechoslovakia
# 210        Romania                2                1  Czechoslovakia
# 214         Brazil                1                0         England
# 218         Brazil                3                2         Romania
# 222        England                1                0  Czechoslovakia
# 236        Uruguay                0                2     Netherlands
# 237         Sweden                0                0        Bulgaria
# 244    Netherlands                0                0          Sweden
# 245       Bulgaria                1                1         Uruguay
# 252       Bulgaria                1                4     Netherlands
# 254         Sweden                3                0         Uruguay
# 274         Sweden                1                1          Brazil
# 275        Austria                2                1           Spain
# 282         Brazil                0                0           Spain
# 283        Austria                1                0          Sweden
# 290         Brazil                1                0         Austria
# 291          Spain                1                0          Sweden
# 308      Argentina                0                1         Belgium
# 312        Hungary               10                1     El Salvador
# 321      Argentina                4                1         Hungary
# 324        Belgium                1                0     El Salvador
# 333        Belgium                1                1         Hungary
# 336      Argentina                2                0     El Salvador
# 346          Italy                2                1       Argentina
# 350      Argentina                1                3          Brazil
# 354          Italy                3                2          Brazil
#
#     Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 3                       2549.0                     1                     0
# 8                      57735.0                     0                     0
# 13                     70022.0                     4                     0
# 53                     81649.0                     1                     0
# 54                     29703.0                     1                     0
# 55                      9511.0                     0                     1
# 56                     36502.0                     2                     1
# 57                      7336.0                     0                     0
# 58                     42032.0                     2                     1
# 59                     11078.0                     2                     0
# 60                     19790.0                     2                     0
# 61                      7903.0                     2                     1
# 62                     10151.0                     1                     0
# 63                    142429.0                     1                     0
# 64                     74462.0                     0                     0
# 65                     25811.0                     1                     0
# 66                      5284.0                     4                     0
# 67                      3580.0                     2                     0
# 68                      8501.0                     2                     0
# 69                     44802.0                     1                     2
# 70                    138886.0                     3                     0
# 71                    152772.0                     3                     0
# 72                      7987.0                     1                     2
# 73                     11227.0                     2                     0
# 74                    173850.0                     0                     0
# 75                     20500.0                     0                     0
# 76                     25000.0                     1                     0
# 83                     34000.0                     2                     0
# 84                     26000.0                     4                     0
# 101                    34107.0                     1                     0
# ..             ...         ...                   ...                   ...
# 180                    25438.0                     2                     0
# 186                    58479.0                     2                     0
# 189                    24129.0                     2                     1
# 203                    50560.0                     0                     0
# 206                    52897.0                     1                     1
# 210                    56818.0                     0                     1
# 214                    66843.0                     0                     0
# 218                    50804.0                     2                     1
# 222                    49292.0                     0                     0
# 236                    55100.0                     0                     1
# 237                    23800.0                     0                     0
# 244                    53700.0                     0                     0
# 245                    13400.0                     0                     0
# 252                    53300.0                     0                     2
# 254                    28300.0                     0                     0
# 274                    32569.0                     1                     1
# 275                    40841.0                     1                     1
# 282                    34771.0                     0                     0
# 283                    41424.0                     1                     0
# 290                    35221.0                     1                     0
# 291                    42132.0                     0                     0
# 308                    95000.0                     0                     0
# 312                    23000.0                     3                     0
# 321                    32093.0                     2                     0
# 324                    15000.0                     1                     0
# 333                    37000.0                     0                     1
# 336                    32500.0                     1                     0
# 346                    43000.0                     0                     0
# 350                    44000.0                     0                     1
# 354                    44000.0                     2                     1
#
#                          Referee                        Assistant 1  \
# 3          WARNKEN Alberto (CHI)                LANGENUS Jean (BEL)
# 8            LANGENUS Jean (BEL)                BALWAY Thomas (FRA)
# 13           REGO Gilberto (BRA)              WARNKEN Alberto (CHI)
# 53           READER George (ENG)           GRIFFITHS Benjamin (WAL)
# 54      VAN DER MEER Karel (NED)               GARDELLI Mario (BRA)
# 55             VIANA Mario (BRA)         DA COSTA VIEIRA Jose (POR)
# 56               LUTZ Jean (SUI)                BERANEK Alois (AUT)
# 57        GALEATI Giovanni (ITA)                  EKLIND Ivan (SWE)
# 58         AZON ROMA Ramon (ESP)            BUSTAMANTE Sergio (CHI)
# 59          LEAFE Reginald (ENG)               DAHLNER Gunnar (SWE)
# 60         MALCHER Alberto (BRA)               MARINO Esteban (URU)
# 61         MITCHELL Robert (SCO)                  LEMESIC Leo (YUG)
# 62        DATTILO Generoso (ITA)          DE LA SALLE Charles (FRA)
# 63      GRIFFITHS Benjamin (WAL)                BERANEK Alois (AUT)
# 64        GALEATI Giovanni (ITA)                    LUTZ Jean (SUI)
# 65            ELLIS Arthur (ENG)             GARCIA Prudencio (USA)
# 66           READER George (ENG)                  VIANA Mario (BRA)
# 67             EKLIND Ivan (SWE)               DAHLNER Gunnar (SWE)
# 68          GARDELLI Mario (BRA)            HEYEN Mario Ruben (PAR)
# 69      GRIFFITHS Benjamin (WAL)             DATTILO Generoso (ITA)
# 70            ELLIS Arthur (ENG)             GARCIA Prudencio (USA)
# 71          LEAFE Reginald (ENG)              MITCHELL George (SCO)
# 72        GALEATI Giovanni (ITA)                BERANEK Alois (AUT)
# 73      VAN DER MEER Karel (NED)                    LUTZ Jean (SUI)
# 74           READER George (ENG)                 ELLIS Arthur (ENG)
# 75            ELLIS Arthur (ENG)                 LING William (ENG)
# 76         FRANKEN Laurent (BEL)                  VIANA Mario (BRA)
# 83      ORLANDINI Vincenzo (ITA)                WYSSLING Paul (SUI)
# 84         STEFANOVIC Vasa (YUG)            DOERFLINGER Ernst (SUI)
# 101       LATYCHEV Nikolaj (URS)                   MOWAT Jack (SCO)
# ..                           ...                                ...
# 180     CODESAL Jose Maria (URU)           GOICOECHEA Roberto (ARG)
# 186          McCABE George (ENG)                CALLAGHAN Leo (WAL)
# 189     GOICOECHEA Roberto (ARG)             GARDEAZABAL Juan (ESP)
# 203           LORAUX Vital (BEL)                 MACHIN Roger (FRA)
# 206     BARRETO RUIZ Ramon (URU)                KLEIN Abraham (ISR)
# 210           DE LEO Diego (MEX)              EMSBERGER Gyula (HUN)
# 214          KLEIN Abraham (ISR)    YAMASAKI MALDONADO Arturo (MEX)
# 218    MARSCHALL Ferdinand (AUT)           BARRETO RUIZ Ramon (URU)
# 222           MACHIN Roger (FRA)              EMSBERGER Gyula (HUN)
# 236         PALOTAI Karoly (HUN)                KAZAKOV Pavel (URS)
# 237  PEREZ NUNEZ Edison A. (PER)   GONZALEZ ARCHUNDIA Alfonso (MEX)
# 244       WINSEMANN Werner (CAN)             TSCHENSCHER Kurt (GER)
# 245            TAYLOR John (ENG)                BABACAN Dogan (TUR)
# 252          BOSKOVIC Tony (AUS)            BIWERSI Ferdinand (GER)
# 254         LINEMAYR Erich (AUT)            LLOBREGAT Vicente (VEN)
# 274           THOMAS Clive (WAL)                JARGUZ Alojzy (POL)
# 275         PALOTAI Karoly (HUN)           BARRETO RUIZ Ramon (URU)
# 282         GONELLA Sergio (ITA)                KLEIN Abraham (ISR)
# 283         CORVER Charles (NED)             MAKSIMOVIC Dusan (SCG)
# 290           WURTZ Robert (FRA)                 BOUZO Farouk (SYR)
# 291      BIWERSI Ferdinand (GER)     ITHURRALDE Arturo Andres (ARG)
# 308       CHRISTOV Vojtech (TCH)               PALOTAI Karoly (HUN)
# 312         AL DOY Ebrahim (BHR)               CORVER Charles (NED)
# 321         LACARNE Belaid (ALG)               VAUTROT Michel (FRA)
# 324        MOFFATT Malcolm (NIR)                CASTRO Gaston (CHI)
# 333            WHITE Clive (ENG)            ESCHWEILER Walter (GER)
# 336         BARRANCOS Luis (BOL)        LAMO CASTILLO Augusto (ESP)
# 346         RAINEA Nicolae (ROU)                 GALLER Bruno (SUI)
# 350    RUBIO VAZQUEZ Mario (MEX)  ARISTIZABAL MURCIA Gilberto (COL)
# 354          KLEIN Abraham (ISR)         CHAN Thomson Tam Sun (HKG)
#
#                          Assistant 2  RoundID  MatchID Home Team Initials  \
# 3           MATEUCCI Francisco (URU)      201     1098                ROU
# 8              CRISTOPHE Henry (BEL)      201     1099                URU
# 13              SAUCEDO Ulises (BOL)      201     1100                URU
# 53             MITCHELL George (SCO)      208     1187                BRA
# 54              DAHLNER Gunnar (SWE)      208     1192                ENG
# 55         DE LA SALLE Charles (FRA)      208     1208                ESP
# 56               TEJADA Carlos (MEX)      208     1219                SWE
# 57            DATTILO Generoso (ITA)      208     1230                YUG
# 58          DE NICOLA Cayetano (PAR)      208     1188                BRA
# 59          VAN DER MEER Karel (NED)      208     1225                YUG
# 60             ALVAREZ Alfredo (BOL)      208     1193                ESP
# 61            GARCIA Prudencio (USA)      208     1228                SWE
# 62            GALEATI Giovanni (ITA)      208     1202                USA
# 63        DA COSTA VIEIRA Jose (POR)      208     1191                BRA
# 64            DATTILO Generoso (ITA)      208     1199                ESP
# 65         DE LA SALLE Charles (FRA)      208     1218                ITA
# 66                 LEMESIC Leo (YUG)      208     1185                URU
# 67           BUSTAMANTE Sergio (CHI)      208     1222                SUI
# 68             ALVAREZ Alfredo (BOL)      208     1194                CHI
# 69             ALVAREZ Alfredo (BOL)      209     1207                URU
# 70         DE LA SALLE Charles (FRA)      209     1189                BRA
# 71        DA COSTA VIEIRA Jose (POR)      209     1186                BRA
# 72          DE NICOLA Cayetano (PAR)      209     1231                URU
# 73            GARCIA Prudencio (USA)      209     1206                SWE
# 74             MITCHELL George (SCO)      209     1190                URU
# 75             SCHICKER Werner (SUI)      211     1315                URU
# 76                 GULDE Josef (SUI)      211     1236                AUT
# 83                GUIDI Denilo (SUI)      211     1313                URU
# 84                 GULDE Josef (SUI)      211     1238                AUT
# 101              ERIKSSON Arne (FIN)      220     1415                SWE
# ..                               ...      ...      ...                ...
# 180           TSCHENSCHER Kurt (GER)      238     1602                POR
# 186            DAGNALL Kenneth (ENG)      238     1598                POR
# 189         CODESAL Jose Maria (URU)      238     1599                HUN
# 203               DE LEO Diego (MEX)      250     1812                ENG
# 206  YAMASAKI MALDONADO Arturo (MEX)      250     1770                BRA
# 210               LORAUX Vital (BEL)      250     1919                ROU
# 214               MACHIN Roger (FRA)      250     1764                BRA
# 218               LORAUX Vital (BEL)      250     1769                BRA
# 222        MARSCHALL Ferdinand (AUT)      250     1813                ENG
# 236             RAINEA Nicolae (ROU)      262     2098                URU
# 237             SUPPIAH George (SIN)      262     1995                SWE
# 244               THOMAS Clive (WAL)      262     2097                NED
# 245               OHMSEN Klaus (GER)      262     1996                BUL
# 252          ESCHWEILER Walter (GER)      262     1990                BUL
# 254             ALDINGER Heinz (GER)      262     2181                SWE
# 274               NAMDAR Jafar (IRN)      278     2253                SWE
# 275             IVANOV Anatoly (URS)      278     2216                AUT
# 282   ITHURRALDE Arturo Andres (ARG)      278     2246                BRA
# 283                SEOUDI Hedi (TUN)      278     2224                AUT
# 290   GEBREYESUS DIFUE Tesfaye (ERI)      278     2215                BRA
# 291               PROKOP Adolf (GDR)      278     2337                ESP
# 308              JARGUZ Alojzy (POL)      293      749                ARG
# 312      LUND-SORENSEN Henning (DEN)      293      896                HUN
# 321             RAINEA Nicolae (ROU)      293      752                ARG
# 324              JARGUZ Alojzy (POL)      293      774                BEL
# 333             LACARNE Belaid (ALG)      293      779                BEL
# 336             LACARNE Belaid (ALG)      293      751                ARG
# 346             LACARNE Belaid (ALG)      294      753                ITA
# 350              CASTRO Gaston (CHI)      294      750                ARG
# 354             DOTCHEV Bogdan (BUL)      294      788                ITA
#
#     Away Team Initials
# 3                  PER
# 8                  PER
# 13                 ROU
# 53                 MEX
# 54                 CHI
# 55                 USA
# 56                 ITA
# 57                 SUI
# 58                 SUI
# 59                 MEX
# 60                 CHI
# 61                 PAR
# 62                 ENG
# 63                 YUG
# 64                 ENG
# 65                 PAR
# 66                 BOL
# 67                 MEX
# 68                 USA
# 69                 ESP
# 70                 SWE
# 71                 ESP
# 72                 SWE
# 73                 ESP
# 74                 BRA
# 75                 TCH
# 76                 SCO
# 83                 SCO
# 84                 TCH
# 101                MEX
# ..                 ...
# 180                BUL
# 186                BRA
# 189                BUL
# 203                ROU
# 206                TCH
# 210                TCH
# 214                ENG
# 218                ROU
# 222                TCH
# 236                NED
# 237                BUL
# 244                SWE
# 245                URU
# 252                NED
# 254                URU
# 274                BRA
# 275                ESP
# 282                ESP
# 283                SWE
# 290                AUT
# 291                SWE
# 308                BEL
# 312                SLV
# 321                HUN
# 324                SLV
# 333                HUN
# 336                SLV
# 346                ARG
# 350                BRA
# 354                BRA
#
# [75 rows x 20 columns]

# %% [markdown]
# Throughout the entire history of the world cup, How many Home games were played by the Netherlands?

# %%
df.loc[df["Home Team Name"]=="Netherlands"].shape[0]
# Out:
# 32

# %% [markdown]
# How many games were played by the Netherlands in total?

# %%
df.loc[(df["Home Team Name"]=="Netherlands") | (df["Away Team Name"]=="Netherlands")].shape[0]
# Out:
# 54

# %% [markdown]
# Next, let's try and figure out how many games the USA played in the 2014 world cup.

# %%
df.loc[(df["Year"]==2014) & ((df["Home Team Name"]=="USA") | (df["Away Team Name"]=="USA"))].shape[0]
# Out:
# 5

# %% [markdown]
# Now, let's try to find out how many countries participated in the 1986 world cup.

# %% [markdown]
# Hint 1: as a first step, create a new data set that only contain games in that year.
#
# Hint 2: You can use `.unique()` to make sure you don't end up with duplicate country names.

# %%
df86 = df.loc[df["Year"]==1986]
df86home = list(df86["Home Team Name"].unique())
df86away = list(df86["Away Team Name"].unique())
df86all = df86home + df86away
type(df86all)


## Need to make "Home Team Name" into a Series, then add the "Away Team Name" to that Series, then pull the ole .unique() and then BAM! Done.
# Out:
# list

# %% [markdown]
# In the world cup history, how matches had more than 5 goals in total?

# %% [markdown]
# ## Changing values and creating new columns

# %% [markdown]
# With the information you currently have in your `df`, create a new column "Half-time Goals".

# %% [markdown]
# Run the code below. You'll notice that for Korea, there are records for both North-Korea (Korea DPR) and South-Korea (Korea Republic).

# %%
df.loc[df["Home Team Name"].str.contains('Korea'), "Home Team Name" ]

# %% [markdown]
# Imagine that for some reason, we simply want Korea listed as one entry, so we want to replace every "Home Team Name" and "Away Team Name" entry that contains "Korea" to simply "Korea". In the same way, we want to change the columns "Home Team Initials" and "Away Team Initials" to NSK (North & South Korea) instead of "KOR" and "PRK".

# %% [markdown]
# Make sure to verify your answer!
